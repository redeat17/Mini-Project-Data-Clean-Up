# %%
# Dependencies
import pandas as pd

# %%
# load CSV
coders = "Resources/2016-FCC-New-Coders-Survey-Data.csv"

# %%
coders_df = pd.read_csv(coders)
coders_df.head()# Read with pandas
# Out:
# C:\Users\redea\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3071: DtypeWarning: Columns (21,57) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#     Age  AttendedBootcamp  BootcampFinish  BootcampFullJobAfter  \
# 0  28.0               0.0             NaN                   NaN
# 1  22.0               0.0             NaN                   NaN
# 2  19.0               0.0             NaN                   NaN
# 3  26.0               0.0             NaN                   NaN
# 4  20.0               0.0             NaN                   NaN
#
#    BootcampLoanYesNo  BootcampMonthsAgo BootcampName  BootcampPostSalary  \
# 0                NaN                NaN          NaN                 NaN
# 1                NaN                NaN          NaN                 NaN
# 2                NaN                NaN          NaN                 NaN
# 3                NaN                NaN          NaN                 NaN
# 4                NaN                NaN          NaN                 NaN
#
#    BootcampRecommend  ChildrenNumber  ... ResourceSoloLearn  \
# 0                NaN             NaN  ...               NaN
# 1                NaN             NaN  ...               NaN
# 2                NaN             NaN  ...               NaN
# 3                NaN             NaN  ...               NaN
# 4                NaN             NaN  ...               NaN
#
#    ResourceStackOverflow  ResourceTreehouse  ResourceUdacity  ResourceUdemy  \
# 0                    NaN                NaN              NaN            NaN
# 1                    NaN                NaN              NaN            1.0
# 2                    NaN                NaN              NaN            NaN
# 3                    NaN                NaN              NaN            NaN
# 4                    NaN                NaN              NaN            NaN
#
#    ResourceW3Schools  ResourceYouTube  \
# 0                NaN              NaN
# 1                NaN              NaN
# 2                NaN              NaN
# 3                NaN              NaN
# 4                NaN              NaN
#
#                               SchoolDegree              SchoolMajor  \
# 0           some college credit, no degree                      NaN
# 1           some college credit, no degree                      NaN
# 2  high school diploma or equivalent (GED)                      NaN
# 3                        bachelor's degree  Cinematography And Film
# 4           some college credit, no degree                      NaN
#
#    StudentDebtOwe
# 0         20000.0
# 1             NaN
# 2             NaN
# 3          7000.0
# 4             NaN
#
# [5 rows x 113 columns]

# %%
# Inspect all columns
coders_df.columns
# Out:
# Index(['Age', 'AttendedBootcamp', 'BootcampFinish', 'BootcampFullJobAfter',
#        'BootcampLoanYesNo', 'BootcampMonthsAgo', 'BootcampName',
#        'BootcampPostSalary', 'BootcampRecommend', 'ChildrenNumber',
#        ...
#        'ResourceSoloLearn', 'ResourceStackOverflow', 'ResourceTreehouse',
#        'ResourceUdacity', 'ResourceUdemy', 'ResourceW3Schools',
#        'ResourceYouTube', 'SchoolDegree', 'SchoolMajor', 'StudentDebtOwe'],
#       dtype='object', length=113)

# %%
# Extract only columns 0, 1, 2, 3, 4, 7, 8, 9, 10,11, 29, 30, 32, 36, 37, 45, 48, 56, 110, 111
new_df = coders_df.iloc[:, [0, 1, 2, 3, 4, 7, 8, 9, 10,11, 29, 30, 32, 36, 37, 45, 48, 56, 110, 111]]
new_df.columns
# Out:
# Index(['Age', 'AttendedBootcamp', 'BootcampFinish', 'BootcampFullJobAfter',
#        'BootcampLoanYesNo', 'BootcampPostSalary', 'BootcampRecommend',
#        'ChildrenNumber', 'CityPopulation', 'CodeEventBootcamp', 'CountryLive',
#        'EmploymentField', 'EmploymentStatus', 'Gender', 'HasChildren',
#        'HoursLearning', 'Income', 'JobRoleInterest', 'SchoolDegree',
#        'SchoolMajor'],
#       dtype='object')

# %%
# Change "0" to "No" and "1" to "Yes" in response columns
yesno_df = new_df.replace({0: "No", 1: "Yes"})

# %%
# Calculate total number of respondents in survey 
total_respondents = len(new_df) #changed variable name from len_respondents to total respondents
total_respondents
# Out:
# 15620

# %%
# Extract rows corresponding only to people who attended a bootcamp
attended = yesno_df.loc[yesno_df["AttendedBootcamp"]=="Yes"]
attended
# Out:
#         Age AttendedBootcamp BootcampFinish BootcampFullJobAfter  \
# 93     32.0              Yes            Yes                   No
# 97     26.0              Yes            Yes                  Yes
# 130    41.0              Yes            Yes                  Yes
# 159    26.0              Yes            Yes                   No
# 188    24.0              Yes             No                  NaN
# ...     ...              ...            ...                  ...
# 15539  39.0              Yes            Yes                  Yes
# 15540  24.0              Yes            Yes                  Yes
# 15541  23.0              Yes            Yes                  Yes
# 15593  29.0              Yes             No                  NaN
# 15600  28.0              Yes            Yes                  Yes
#
#       BootcampLoanYesNo  BootcampPostSalary BootcampRecommend ChildrenNumber  \
# 93                   No                 NaN                No            NaN
# 97                   No             45000.0                No            NaN
# 130                 Yes             75000.0               Yes              3
# 159                  No                 NaN                No            NaN
# 188                 Yes                 NaN                No            NaN
# ...                 ...                 ...               ...            ...
# 15539               Yes                 NaN               Yes            NaN
# 15540               Yes                 NaN                No            NaN
# 15541                No             21600.0               Yes            NaN
# 15593                No                 NaN                No            NaN
# 15600                No             36000.0               Yes            NaN
#
#                       CityPopulation CodeEventBootcamp  \
# 93     between 100,000 and 1 million               NaN
# 97               more than 1 million               NaN
# 130                less than 100,000               NaN
# 159    between 100,000 and 1 million               NaN
# 188    between 100,000 and 1 million               NaN
# ...                              ...               ...
# 15539            more than 1 million               NaN
# 15540            more than 1 million               NaN
# 15541            more than 1 million               NaN
# 15593            more than 1 million               NaN
# 15600  between 100,000 and 1 million               NaN
#
#                     CountryLive                        EmploymentField  \
# 93     United States of America  arts, entertainment, sports, or media
# 97     United States of America                   software development
# 130    United States of America                   software development
# 159    United States of America                                    NaN
# 188                      Canada                                    NaN
# ...                         ...                                    ...
# 15539                    Mexico                                    NaN
# 15540                     Kenya  arts, entertainment, sports, or media
# 15541                    Mexico            software development and IT
# 15593                     India            software development and IT
# 15600  United States of America            software development and IT
#
#                            EmploymentStatus  Gender HasChildren HoursLearning  \
# 93             Self-employed business owner    male         NaN            20
# 97                       Employed for wages    male          No            10
# 130                      Employed for wages    male         Yes            30
# 159    Not working and not looking for work  female         NaN            30
# 188        Not working but looking for work  female         NaN            60
# ...                                     ...     ...         ...           ...
# 15539              Self-employed freelancer  female         NaN            15
# 15540                    Employed for wages  female         NaN            10
# 15541                    Employed for wages    male         NaN            24
# 15593                    Employed for wages  female          No             5
# 15600                    Employed for wages  female         NaN             8
#
#          Income           JobRoleInterest                        SchoolDegree  \
# 93      67000.0                       NaN                   bachelor's degree
# 97      40000.0                       NaN  master's degree (non-professional)
# 130     75000.0                       NaN      some college credit, no degree
# 159         NaN  Full-Stack Web Developer      some college credit, no degree
# 188         NaN                       NaN      some college credit, no degree
# ...         ...                       ...                                 ...
# 15539   36000.0  Full-Stack Web Developer      some college credit, no degree
# 15540   16800.0                       NaN                   bachelor's degree
# 15541   42000.0                       NaN  master's degree (non-professional)
# 15593  200000.0                       NaN                   bachelor's degree
# 15600  200000.0                       NaN                   bachelor's degree
#
#                                              SchoolMajor
# 93                                               Biology
# 97                                                 Music
# 130                                                  NaN
# 159                                                  NaN
# 188                                                  NaN
# ...                                                  ...
# 15539                                                NaN
# 15540  Computer Systems Networking and Telecommunicat...
# 15541                      Computer Software Engineering
# 15593                                         Accounting
# 15600                                          Marketing
#
# [953 rows x 20 columns]

# %%
# Calculate average age of attendees
avg_age = attended["Age"].mean()
print(round(avg_age, 3))

# Calculate how many people attended a bootcamp
len_attended = len(attended)
len_attended

# Calculate how many attendees hold degrees
#degrees = attended["SchoolDegree"].value_counts()
degrees = new_df["SchoolDegree"].unique()
for x in ["SchoolDegree"]:
    rename = new_df.rename({"some college credit": "No", ""})
rename.tail(50)
# Count number of attendees who self-identify as male; female; or are of non-binary gender identification

# Calculate percentage of respondents who attended a bootcamp

# Calculate percentage of respondents belonging to each gender

# Calculate percentage of attendees with a school degree

# Calculate average post-bootcamp salary
# Out:
# 31.066
#         Age  AttendedBootcamp  BootcampFinish  BootcampFullJobAfter  \
# 15570  38.0               0.0             NaN                   NaN
# 15571  34.0               0.0             NaN                   NaN
# 15572  48.0               0.0             NaN                   NaN
# 15573  32.0               0.0             NaN                   NaN
# 15574  31.0               0.0             NaN                   NaN
# 15575  30.0               0.0             NaN                   NaN
# 15576  24.0               0.0             NaN                   NaN
# 15577  34.0               0.0             NaN                   NaN
# 15578  22.0               0.0             NaN                   NaN
# 15579  34.0               0.0             NaN                   NaN
# 15580  53.0               0.0             NaN                   NaN
# 15581  34.0               0.0             NaN                   NaN
# 15582  36.0               0.0             NaN                   NaN
# 15583  31.0               0.0             NaN                   NaN
# 15584  40.0               0.0             NaN                   NaN
# 15585  54.0               0.0             NaN                   NaN
# 15586  29.0               0.0             NaN                   NaN
# 15587  36.0               0.0             NaN                   NaN
# 15588  36.0               0.0             NaN                   NaN
# 15589  28.0               0.0             NaN                   NaN
# 15590  25.0               0.0             NaN                   NaN
# 15591  25.0               0.0             NaN                   NaN
# 15592  43.0               0.0             NaN                   NaN
# 15593  29.0               1.0             0.0                   NaN
# 15594  36.0               0.0             NaN                   NaN
# 15595  30.0               0.0             NaN                   NaN
# 15596  30.0               0.0             NaN                   NaN
# 15597  30.0               0.0             NaN                   NaN
# 15598  28.0               0.0             NaN                   NaN
# 15599  37.0               0.0             NaN                   NaN
# 15600  28.0               1.0             1.0                   1.0
# 15601  25.0               0.0             NaN                   NaN
# 15602  22.0               0.0             NaN                   NaN
# 15603  33.0               0.0             NaN                   NaN
# 15604  35.0               0.0             NaN                   NaN
# 15605  31.0               0.0             NaN                   NaN
# 15606  43.0               0.0             NaN                   NaN
# 15607  25.0               0.0             NaN                   NaN
# 15608  43.0               0.0             NaN                   NaN
# 15609  33.0               0.0             NaN                   NaN
# 15610  29.0               0.0             NaN                   NaN
# 15611  37.0               0.0             NaN                   NaN
# 15612  45.0               0.0             NaN                   NaN
# 15613  30.0               0.0             NaN                   NaN
# 15614  47.0               0.0             NaN                   NaN
# 15615  39.0               0.0             NaN                   NaN
# 15616  27.0               0.0             NaN                   NaN
# 15617  37.0               0.0             NaN                   NaN
# 15618  26.0               0.0             NaN                   NaN
# 15619  22.0               0.0             NaN                   NaN
#
#        BootcampLoanYesNo  BootcampPostSalary  BootcampRecommend  \
# 15570                NaN                 NaN                NaN
# 15571                NaN                 NaN                NaN
# 15572                NaN                 NaN                NaN
# 15573                NaN                 NaN                NaN
# 15574                NaN                 NaN                NaN
# 15575                NaN                 NaN                NaN
# 15576                NaN                 NaN                NaN
# 15577                NaN                 NaN                NaN
# 15578                NaN                 NaN                NaN
# 15579                NaN                 NaN                NaN
# 15580                NaN                 NaN                NaN
# 15581                NaN                 NaN                NaN
# 15582                NaN                 NaN                NaN
# 15583                NaN                 NaN                NaN
# 15584                NaN                 NaN                NaN
# 15585                NaN                 NaN                NaN
# 15586                NaN                 NaN                NaN
# 15587                NaN                 NaN                NaN
# 15588                NaN                 NaN                NaN
# 15589                NaN                 NaN                NaN
# 15590                NaN                 NaN                NaN
# 15591                NaN                 NaN                NaN
# 15592                NaN                 NaN                NaN
# 15593                0.0                 NaN                0.0
# 15594                NaN                 NaN                NaN
# 15595                NaN                 NaN                NaN
# 15596                NaN                 NaN                NaN
# 15597                NaN                 NaN                NaN
# 15598                NaN                 NaN                NaN
# 15599                NaN                 NaN                NaN
# 15600                0.0             36000.0                1.0
# 15601                NaN                 NaN                NaN
# 15602                NaN                 NaN                NaN
# 15603                NaN                 NaN                NaN
# 15604                NaN                 NaN                NaN
# 15605                NaN                 NaN                NaN
# 15606                NaN                 NaN                NaN
# 15607                NaN                 NaN                NaN
# 15608                NaN                 NaN                NaN
# 15609                NaN                 NaN                NaN
# 15610                NaN                 NaN                NaN
# 15611                NaN                 NaN                NaN
# 15612                NaN                 NaN                NaN
# 15613                NaN                 NaN                NaN
# 15614                NaN                 NaN                NaN
# 15615                NaN                 NaN                NaN
# 15616                NaN                 NaN                NaN
# 15617                NaN                 NaN                NaN
# 15618                NaN                 NaN                NaN
# 15619                NaN                 NaN                NaN
#
#        ChildrenNumber                 CityPopulation  CodeEventBootcamp  \
# 15570             NaN            more than 1 million                NaN
# 15571             NaN            more than 1 million                NaN
# 15572             2.0              less than 100,000                NaN
# 15573             2.0            more than 1 million                NaN
# 15574             NaN  between 100,000 and 1 million                NaN
# 15575             NaN            more than 1 million                NaN
# 15576             NaN  between 100,000 and 1 million                NaN
# 15577             NaN            more than 1 million                NaN
# 15578             NaN  between 100,000 and 1 million                NaN
# 15579             1.0  between 100,000 and 1 million                NaN
# 15580             3.0            more than 1 million                NaN
# 15581             NaN              less than 100,000                NaN
# 15582             1.0            more than 1 million                NaN
# 15583             NaN            more than 1 million                NaN
# 15584             3.0            more than 1 million                NaN
# 15585             4.0            more than 1 million                NaN
# 15586             1.0            more than 1 million                NaN
# 15587             NaN            more than 1 million                NaN
# 15588             1.0            more than 1 million                NaN
# 15589             NaN              less than 100,000                NaN
# 15590             NaN            more than 1 million                NaN
# 15591             NaN            more than 1 million                NaN
# 15592             1.0  between 100,000 and 1 million                NaN
# 15593             NaN            more than 1 million                NaN
# 15594             2.0            more than 1 million                NaN
# 15595             NaN            more than 1 million                NaN
# 15596             2.0              less than 100,000                NaN
# 15597             NaN            more than 1 million                NaN
# 15598             1.0              less than 100,000                NaN
# 15599             NaN  between 100,000 and 1 million                NaN
# 15600             NaN  between 100,000 and 1 million                NaN
# 15601             NaN  between 100,000 and 1 million                NaN
# 15602             NaN  between 100,000 and 1 million                NaN
# 15603             NaN            more than 1 million                NaN
# 15604             NaN              less than 100,000                NaN
# 15605             NaN            more than 1 million                NaN
# 15606             3.0            more than 1 million                NaN
# 15607             NaN            more than 1 million                NaN
# 15608             2.0            more than 1 million                NaN
# 15609             NaN            more than 1 million                NaN
# 15610             NaN            more than 1 million                NaN
# 15611             1.0            more than 1 million                NaN
# 15612             NaN  between 100,000 and 1 million                NaN
# 15613             2.0            more than 1 million                NaN
# 15614             NaN  between 100,000 and 1 million                NaN
# 15615             NaN            more than 1 million                NaN
# 15616             NaN            more than 1 million                NaN
# 15617             NaN            more than 1 million                NaN
# 15618             NaN            more than 1 million                NaN
# 15619             NaN            more than 1 million                NaN
#
#                     CountryLive                        EmploymentField  \
# 15570  United States of America            software development and IT
# 15571  United States of America                                    NaN
# 15572  United States of America  arts, entertainment, sports, or media
# 15573  United States of America                                  legal
# 15574            United Kingdom            software development and IT
# 15575  United States of America            software development and IT
# 15576  United States of America                                    NaN
# 15577  United States of America            software development and IT
# 15578                     India            software development and IT
# 15579  United States of America                                  sales
# 15580  United States of America            software development and IT
# 15581  United States of America            software development and IT
# 15582            United Kingdom            software development and IT
# 15583            United Kingdom            software development and IT
# 15584                 Australia            software development and IT
# 15585  United States of America            software development and IT
# 15586            United Kingdom            software development and IT
# 15587  United States of America            software development and IT
# 15588  United States of America            software development and IT
# 15589                  Colombia            software development and IT
# 15590                     India            software development and IT
# 15591                    Brazil            software development and IT
# 15592  United States of America            software development and IT
# 15593                     India            software development and IT
# 15594  United States of America                                finance
# 15595                   Ukraine            software development and IT
# 15596                    Brazil            software development and IT
# 15597                   Ukraine                                  legal
# 15598  United States of America                      food and beverage
# 15599  United States of America            software development and IT
# 15600  United States of America            software development and IT
# 15601  United States of America                                  legal
# 15602                     India            software development and IT
# 15603  United States of America            software development and IT
# 15604                    Norway            construction and extraction
# 15605                  Portugal            software development and IT
# 15606                    Canada                                  legal
# 15607               Philippines                   software development
# 15608  United States of America                            health care
# 15609                    Mexico            software development and IT
# 15610  United States of America                              education
# 15611                    Canada            software development and IT
# 15612  United States of America                                    NaN
# 15613              South Africa            software development and IT
# 15614  United States of America                                finance
# 15615                     Kenya            software development and IT
# 15616                     India            software development and IT
# 15617                   Nigeria                                    NaN
# 15618                     Spain                              education
# 15619  United States of America  arts, entertainment, sports, or media
#
#                    EmploymentStatus  Gender  HasChildren  HoursLearning  \
# 15570            Employed for wages    male          NaN          100.0
# 15571            Employed for wages    male          NaN            4.0
# 15572      Self-employed freelancer  female          1.0           10.0
# 15573            Employed for wages    male          1.0            1.0
# 15574            Employed for wages    male          NaN            1.0
# 15575            Employed for wages    male          NaN           15.0
# 15576            Employed for wages    male          0.0            NaN
# 15577            Employed for wages    male          NaN            4.0
# 15578            Employed for wages    male          0.0           25.0
# 15579            Employed for wages    male          1.0            3.0
# 15580  Self-employed business owner    male          1.0           10.0
# 15581            Employed for wages    male          NaN            2.0
# 15582            Employed for wages    male          1.0           69.0
# 15583  Self-employed business owner    male          0.0            8.0
# 15584            Employed for wages    male          1.0           10.0
# 15585            Employed for wages    male          1.0           10.0
# 15586            Employed for wages    male          1.0            8.0
# 15587            Employed for wages    male          NaN            3.0
# 15588            Employed for wages    male          1.0           10.0
# 15589            Employed for wages    male          0.0            5.0
# 15590            Employed for wages    male          NaN            2.0
# 15591            Employed for wages    male          0.0            2.0
# 15592            Employed for wages    male          1.0            3.0
# 15593            Employed for wages  female          0.0            5.0
# 15594            Employed for wages    male          1.0            1.0
# 15595      Self-employed freelancer    male          0.0           30.0
# 15596            Employed for wages    male          1.0            2.0
# 15597      Self-employed freelancer    male          NaN            6.0
# 15598            Employed for wages    male          1.0           20.0
# 15599            Employed for wages    male          NaN            5.0
# 15600            Employed for wages  female          NaN            8.0
# 15601            Employed for wages    male          NaN           10.0
# 15602            Employed for wages    male          NaN           50.0
# 15603            Employed for wages    male          NaN            4.0
# 15604            Employed for wages    male          NaN            5.0
# 15605            Employed for wages    male          NaN            5.0
# 15606  Self-employed business owner    male          1.0            3.0
# 15607      Self-employed freelancer    male          0.0            8.0
# 15608            Employed for wages    male          1.0            6.0
# 15609            Employed for wages    male          0.0           16.0
# 15610            Employed for wages    male          NaN            5.0
# 15611  Self-employed business owner    male          1.0           40.0
# 15612            Employed for wages  female          NaN            2.0
# 15613            Employed for wages    male          1.0            4.0
# 15614            Employed for wages    male          NaN            3.0
# 15615      Self-employed freelancer    male          0.0           40.0
# 15616            Employed for wages    male          0.0           15.0
# 15617      Self-employed freelancer    male          NaN           14.0
# 15618      Self-employed freelancer    male          NaN           10.0
# 15619            Employed for wages  female          0.0            2.0
#
#          Income                   JobRoleInterest  \
# 15570  200000.0                               NaN
# 15571  200000.0                               NaN
# 15572  200000.0                               NaN
# 15573  200000.0                               NaN
# 15574  200000.0                               NaN
# 15575  200000.0                               NaN
# 15576  200000.0                               NaN
# 15577  200000.0                               NaN
# 15578  200000.0                               NaN
# 15579  200000.0                               NaN
# 15580  200000.0                               NaN
# 15581  200000.0                               NaN
# 15582  200000.0                               NaN
# 15583  200000.0                               NaN
# 15584  200000.0                 DevOps / SysAdmin
# 15585  200000.0                               NaN
# 15586  200000.0                               NaN
# 15587  200000.0                               NaN
# 15588  200000.0                               NaN
# 15589  200000.0                               NaN
# 15590  200000.0                               NaN
# 15591  200000.0                               NaN
# 15592  200000.0                               NaN
# 15593  200000.0                               NaN
# 15594  200000.0                               NaN
# 15595  200000.0                               NaN
# 15596  200000.0                               NaN
# 15597  200000.0                               NaN
# 15598  200000.0          Full-Stack Web Developer
# 15599  200000.0                               NaN
# 15600  200000.0                               NaN
# 15601  200000.0                               NaN
# 15602  200000.0    Data Scientist / Data Engineer
# 15603  200000.0                               NaN
# 15604  200000.0           Front-End Web Developer
# 15605  200000.0          Full-Stack Web Developer
# 15606  200000.0                               NaN
# 15607  200000.0                               NaN
# 15608  200000.0                               NaN
# 15609  200000.0                               NaN
# 15610  200000.0           Front-End Web Developer
# 15611  200000.0                               NaN
# 15612  200000.0                               NaN
# 15613  200000.0                               NaN
# 15614   26000.0                               NaN
# 15615   10000.0                               NaN
# 15616   10000.0           Front-End Web Developer
# 15617   48000.0                               NaN
# 15618   10000.0                               NaN
# 15619   18000.0                               NaN
#
#                                    SchoolDegree  \
# 15570                                     Ph.D.
# 15571                         bachelor's degree
# 15572                         bachelor's degree
# 15573   professional degree (MBA, MD, JD, etc.)
# 15574                         bachelor's degree
# 15575        master's degree (non-professional)
# 15576                         bachelor's degree
# 15577        master's degree (non-professional)
# 15578                         bachelor's degree
# 15579        master's degree (non-professional)
# 15580   professional degree (MBA, MD, JD, etc.)
# 15581            some college credit, no degree
# 15582                          some high school
# 15583                         bachelor's degree
# 15584                         bachelor's degree
# 15585                         bachelor's degree
# 15586                         bachelor's degree
# 15587                         bachelor's degree
# 15588        master's degree (non-professional)
# 15589  trade, technical, or vocational training
# 15590                         bachelor's degree
# 15591   professional degree (MBA, MD, JD, etc.)
# 15592   high school diploma or equivalent (GED)
# 15593                         bachelor's degree
# 15594                         bachelor's degree
# 15595                          some high school
# 15596   high school diploma or equivalent (GED)
# 15597   professional degree (MBA, MD, JD, etc.)
# 15598                        associate's degree
# 15599            some college credit, no degree
# 15600                         bachelor's degree
# 15601                         bachelor's degree
# 15602                         bachelor's degree
# 15603                         bachelor's degree
# 15604            some college credit, no degree
# 15605   high school diploma or equivalent (GED)
# 15606                         bachelor's degree
# 15607         no high school (secondary school)
# 15608   professional degree (MBA, MD, JD, etc.)
# 15609                         bachelor's degree
# 15610        master's degree (non-professional)
# 15611   professional degree (MBA, MD, JD, etc.)
# 15612            some college credit, no degree
# 15613  trade, technical, or vocational training
# 15614  trade, technical, or vocational training
# 15615                         bachelor's degree
# 15616                         bachelor's degree
# 15617                         bachelor's degree
# 15618        master's degree (non-professional)
# 15619                         bachelor's degree
#
#                                              SchoolMajor
# 15570                                   Computer Science
# 15571                                         Psychology
# 15572                                        Art History
# 15573          Bioengineering and Biomedical Engineering
# 15574                                     Graphic Design
# 15575             Electrical and Electronics Engineering
# 15576                                Information Systems
# 15577                                   Computer Science
# 15578                                   Computer Science
# 15579                                            Physics
# 15580                                            History
# 15581                                                NaN
# 15582                                                NaN
# 15583                                   Computer Science
# 15584                          Computer Systems Analysis
# 15585                   Computer and Information Studies
# 15586                                   Computer Science
# 15587                                   Computer Science
# 15588                             Electrical Engineering
# 15589                                                NaN
# 15590                                   Computer Science
# 15591  Computer Systems Networking and Telecommunicat...
# 15592                                                NaN
# 15593                                         Accounting
# 15594                                        Engineering
# 15595                                                NaN
# 15596                                                NaN
# 15597                                                Law
# 15598          Computer and Information Systems Security
# 15599                                                NaN
# 15600                                          Marketing
# 15601                Criminal Justice and Safety Studies
# 15602                                        Mathematics
# 15603                                   Computer Science
# 15604                                                NaN
# 15605                                                NaN
# 15606                                            Physics
# 15607                                                NaN
# 15608                             Electrical Engineering
# 15609                               Software Engineering
# 15610                                  Religious Studies
# 15611             Electrical and Electronics Engineering
# 15612                                                NaN
# 15613                                                NaN
# 15614                                                NaN
# 15615                                          Chemistry
# 15616                             Electrical Engineering
# 15617                                          Chemistry
# 15618                                               Math
# 15619                                     Graphic Design

# %%
#degrees_data = new_df.rename(bachelor's degree: "Yes": "No"}, {bachelor's degree: "Yes"})
new_df["SchoolDegree"] = new_df["SchoolDegree"].replace(
 {"bachelor's degree": "Yes", "bachelor's degree": "Yes"})
print(new_df["SchoolDegree"])
# no degree, high school diploma or equivalent (GED), trade, technical, or vocational training, some high school, nan, no high school (secondary school)
# Out:
# 0                 some college credit, no degree
# 1                 some college credit, no degree
# 2        high school diploma or equivalent (GED)
# 3                                            Yes
# 4                 some college credit, no degree
#                           ...
# 15615                                        Yes
# 15616                                        Yes
# 15617                                        Yes
# 15618         master's degree (non-professional)
# 15619                                        Yes
# Name: SchoolDegree, Length: 15620, dtype: object
# <ipython-input-35-8cdfa1e803b4>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["SchoolDegree"] = new_df["SchoolDegree"].replace(

# %%
# Create a new table consolodating above calculations

# %%
# Improve formatting before outputting spreadsheet

# %%
# Export to Excel
