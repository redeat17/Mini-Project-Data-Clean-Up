# %%
# Dependencies
import pandas as pd

# %%
# load CSV
coders = "Resources/2016-FCC-New-Coders-Survey-Data.csv"

# %%
# Read with pandas
coders_df = pd.read_csv(coders, encoding = 'iso-8859-1', low_memory=False)
coders_df.head()
# Out:
#     Age  AttendedBootcamp  BootcampFinish  BootcampFullJobAfter  \
# 0  28.0               0.0             NaN                   NaN
# 1  22.0               0.0             NaN                   NaN
# 2  19.0               0.0             NaN                   NaN
# 3  26.0               0.0             NaN                   NaN
# 4  20.0               0.0             NaN                   NaN
#
#    BootcampLoanYesNo  BootcampMonthsAgo BootcampName  BootcampPostSalary  \
# 0                NaN                NaN          NaN                 NaN
# 1                NaN                NaN          NaN                 NaN
# 2                NaN                NaN          NaN                 NaN
# 3                NaN                NaN          NaN                 NaN
# 4                NaN                NaN          NaN                 NaN
#
#    BootcampRecommend  ChildrenNumber  ... ResourceSoloLearn  \
# 0                NaN             NaN  ...               NaN
# 1                NaN             NaN  ...               NaN
# 2                NaN             NaN  ...               NaN
# 3                NaN             NaN  ...               NaN
# 4                NaN             NaN  ...               NaN
#
#    ResourceStackOverflow  ResourceTreehouse  ResourceUdacity  ResourceUdemy  \
# 0                    NaN                NaN              NaN            NaN
# 1                    NaN                NaN              NaN            1.0
# 2                    NaN                NaN              NaN            NaN
# 3                    NaN                NaN              NaN            NaN
# 4                    NaN                NaN              NaN            NaN
#
#    ResourceW3Schools  ResourceYouTube  \
# 0                NaN              NaN
# 1                NaN              NaN
# 2                NaN              NaN
# 3                NaN              NaN
# 4                NaN              NaN
#
#                               SchoolDegree              SchoolMajor  \
# 0           some college credit, no degree                      NaN
# 1           some college credit, no degree                      NaN
# 2  high school diploma or equivalent (GED)                      NaN
# 3                        bachelor's degree  Cinematography And Film
# 4           some college credit, no degree                      NaN
#
#    StudentDebtOwe
# 0         20000.0
# 1             NaN
# 2             NaN
# 3          7000.0
# 4             NaN
#
# [5 rows x 113 columns]

# %%
# Inspect all columns
coders_df.columns
# Out:
# Index(['Age', 'AttendedBootcamp', 'BootcampFinish', 'BootcampFullJobAfter',
#        'BootcampLoanYesNo', 'BootcampMonthsAgo', 'BootcampName',
#        'BootcampPostSalary', 'BootcampRecommend', 'ChildrenNumber',
#        ...
#        'ResourceSoloLearn', 'ResourceStackOverflow', 'ResourceTreehouse',
#        'ResourceUdacity', 'ResourceUdemy', 'ResourceW3Schools',
#        'ResourceYouTube', 'SchoolDegree', 'SchoolMajor', 'StudentDebtOwe'],
#       dtype='object', length=113)

# %%
# Extract only columns 0, 1, 2, 3, 4, 7, 8, 9, 10,11, 29, 30, 32, 36, 37, 45, 48, 56, 110, 111
new_df = coders_df.iloc[:, [0, 1, 2, 3, 4, 7, 8, 9, 10,11, 29, 30, 32, 36, 37, 45, 48, 56, 110, 111]]
new_df.columns
# Out:
# Index(['Age', 'AttendedBootcamp', 'BootcampFinish', 'BootcampFullJobAfter',
#        'BootcampLoanYesNo', 'BootcampPostSalary', 'BootcampRecommend',
#        'ChildrenNumber', 'CityPopulation', 'CodeEventBootcamp', 'CountryLive',
#        'EmploymentField', 'EmploymentStatus', 'Gender', 'HasChildren',
#        'HoursLearning', 'Income', 'JobRoleInterest', 'SchoolDegree',
#        'SchoolMajor'],
#       dtype='object')

# %%
# Change "0" to "No" and "1" to "Yes" in response columns
yesno_df = new_df.replace({0: "No", 1: "Yes"})

# %%
# Calculate total number of respondents in survey 
len_respondents = len(new_df) #changed variable name from len_respondents to total respondents
len_respondents
# Out:
# 15620

# %%
# Extract rows corresponding only to people who attended a bootcamp
df_attended = new_df.loc[yesno_df["AttendedBootcamp"]=="Yes"]
df_attended.head()
# Out:
#       Age  AttendedBootcamp  BootcampFinish  BootcampFullJobAfter  \
# 93   32.0               1.0             1.0                   0.0
# 97   26.0               1.0             1.0                   1.0
# 130  41.0               1.0             1.0                   1.0
# 159  26.0               1.0             1.0                   0.0
# 188  24.0               1.0             0.0                   NaN
#
#      BootcampLoanYesNo  BootcampPostSalary  BootcampRecommend  ChildrenNumber  \
# 93                 0.0                 NaN                0.0             NaN
# 97                 0.0             45000.0                0.0             NaN
# 130                1.0             75000.0                1.0             3.0
# 159                0.0                 NaN                0.0             NaN
# 188                1.0                 NaN                0.0             NaN
#
#                     CityPopulation  CodeEventBootcamp  \
# 93   between 100,000 and 1 million                NaN
# 97             more than 1 million                NaN
# 130              less than 100,000                NaN
# 159  between 100,000 and 1 million                NaN
# 188  between 100,000 and 1 million                NaN
#
#                   CountryLive                        EmploymentField  \
# 93   United States of America  arts, entertainment, sports, or media
# 97   United States of America                   software development
# 130  United States of America                   software development
# 159  United States of America                                    NaN
# 188                    Canada                                    NaN
#
#                          EmploymentStatus  Gender  HasChildren  HoursLearning  \
# 93           Self-employed business owner    male          NaN           20.0
# 97                     Employed for wages    male          0.0           10.0
# 130                    Employed for wages    male          1.0           30.0
# 159  Not working and not looking for work  female          NaN           30.0
# 188      Not working but looking for work  female          NaN           60.0
#
#       Income           JobRoleInterest                        SchoolDegree  \
# 93   67000.0                       NaN                   bachelor's degree
# 97   40000.0                       NaN  master's degree (non-professional)
# 130  75000.0                       NaN      some college credit, no degree
# 159      NaN  Full-Stack Web Developer      some college credit, no degree
# 188      NaN                       NaN      some college credit, no degree
#
#     SchoolMajor
# 93      Biology
# 97        Music
# 130         NaN
# 159         NaN
# 188         NaN

# %%
# Calculate average age of attendees
avg = df_attended['Age'].astype(float).mean()
avg

# Calculate how many people attended a bootcamp
len_attended = len(attended)
len_attended
# Out:
# 953

# %%
# Calculate how many attendees hold degrees
#df_attended['SchoolDegree'].unique()




#
#df_attended['SchoolDegree'].unique(["bachelor's degree", "master's degree (non-professional)", 'some college credit, 
                                    #'no degree','professional degree (MBA, MD, JD, etc.)', "associate's degree",
                                    #'trade, technical, or vocational training',
                                    #'high school diploma or equivalent (GED)', 'nan', 'no high school (secondary school)',
                                    #'Ph.D.', 'some high school'])  
    #degrees = new_df["SchoolDegree"].unique()
    #for x in new_df.loc[:, "SchoolDegree"]:
    #rename = new_df.rename({"some college credit": "No",})
degrees = df_attended["SchoolDegree"].value_counts()

# %%
# Count number of attendees who self-identify as male; female; or are of non-binary gender identification
dummy = pd.get_dummies(df_attended['Gender'])
male_count = dummy['male'].sum()
female_count= dummy['female'].sum()
non_binary_count = len(df_attended) - (male_count+female_count)
male_count
# Out:
# 496

# %%
# Calculate percentage of respondents who attended a bootcamp
percent_attended = round((len(df_attended)/len(new_df))*100, 2)


# Calculate percentage of respondents belonging to each gender
perc_male = round((male_count/len(df_attended))*100, 2)
perc_female = round((female_count/len(df_attended))*100, 2)
perc_non_binary = round((non_binary_count/len(df_attended))*100, 2)


# Calculate percentage of attendees with a school degree
percentage_degrees = round((degrees/len(df_attended)*100,2))


# Calculate average post-bootcamp salary
salary = round(df_attended['BootcampPostSalary'].astype(float).mean())*100/100
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-52-2426a08d78b8> in <module>
#      10
#      11 # Calculate percentage of attendees with a school degree
# ---> 12 percentage_degrees = round((degrees/len(df_attended)*100,2))
#      13
#      14
#
# TypeError: type tuple doesn't define __round__ method

# %%
# Create a new table consolodating above calculations
attended_df = pd.DataFrame({"Total # Respondants": [len_respondents], 
                             "Total # Attendees":[attended],
                             "Avg Age of Attendees":[avg],
                             "Attendees %":[percent_attended],
                             "Degrees %":[percentage_degrees],
                             "Male %":[perc_male],
                             "Female %":[perc_female ],
                             "Other Gender %":[perc_non_binary],
                             "Avgerage Salary After BC":[salary]
                            })
attended_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-49-2aa6308ba3da> in <module>
#       4                              "Avg Age of Attendees":[avg],
#       5                              "Attendees %":[percent_attended],
# ----> 6                              "Degrees %":[percentage_degrees],
#       7                              "Male %":[perc_male],
#       8                              "Female %":[perc_female ],
#
# NameError: name 'percentage_degrees' is not defined

# %%
# Improve formatting before outputting spreadsheet
attended_df['Avg Age of Attendees']=attended_df['Avg Age of Attendees'].map('{:.2f}'.format)
attended_df['Attendees %']=attended_df['Attendees %'].map('{:.2f}%'.format)
attended_df['Degrees %']=attended_df['Degrees %'].map('{:.2f}%'.format)
attended_df['Male %']=attended_df['Male %'].map('{:.2f}%'.format)
attended_df['Female %']=attended_df['Female %'].map('{:.2f}%'.format)
attended_df['Other Gender %']=attended_df['Other Gender %'].map('{:.2f}%'.format)
attended_df['Avgerage Salary After BC']=attended_df['Avgerage Salary After BC'].map('${:.2f}'.format)
attended_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-50-4dc458b36062> in <module>
#       1 # Improve formatting before outputting spreadsheet
# ----> 2 attended_df['Avg Age of Attendees']=attended_df['Avg Age of Attendees'].map('{:.2f}'.format)
#       3 attended_df['Attendees %']=attended_df['Attendees %'].map('{:.2f}%'.format)
#       4 attended_df['Degrees %']=attended_df['Degrees %'].map('{:.2f}%'.format)
#       5 attended_df['Male %']=attended_df['Male %'].map('{:.2f}%'.format)
#
# NameError: name 'attended_df' is not defined

# %%
# Export to Excel
attended_df.to_csv("output/des_output.csv", index=False, header=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-51-05d96939186a> in <module>
#       1 # Export to Excel
# ----> 2 attended_df.to_csv("output/des_output.csv", index=False, header=True)
#
# NameError: name 'attended_df' is not defined
